# %% [markdown]
# # Supplementary Fig. S5: Norman generalization context panels
#
# This notebook is the authoritative figure-generation entrypoint. Executing it writes the panel files and final composite through the shared notebook helper `notebooks/_figure_helpers.py`; do not call a standalone figure-rendering script for this figure.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd().resolve()
while repo_root != repo_root.parent and not (repo_root / 'scripts').exists():
    repo_root = repo_root.parent
if not (repo_root / 'scripts').exists():
    raise RuntimeError(f'Could not resolve repository root from {Path.cwd()}')
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))
if str(repo_root / 'src') not in sys.path:
    sys.path.insert(0, str(repo_root / 'src'))
if str(repo_root / 'notebooks') not in sys.path:
    sys.path.insert(0, str(repo_root / 'notebooks'))
from _figure_helpers import render
out = render('figs5')
print(f'Wrote {out}')
