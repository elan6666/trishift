# %% [markdown]
# # Figure S3: Conventional unseen benchmark backup
#
# This notebook is intentionally thin: all plotting logic lives in `scripts/trishift/analysis/render_refresh_figures.py` so the server-side figure plan is reproducible and shared across notebook execution and final packaging.

# %%
from pathlib import Path
import sys
repo_root = Path.cwd()
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))
from scripts.trishift.analysis.render_refresh_figures import render
out = render('figs3')
print(f'Wrote {out}')
