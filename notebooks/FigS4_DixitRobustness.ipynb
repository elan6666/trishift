# %% [markdown]
# # Supplementary Fig. S4: Dixit robustness diagnostics
#
# This notebook renders distance-stratified Dixit robustness panels, using train-distance bins where available.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd().resolve()
while repo_root != repo_root.parent and not (repo_root / 'scripts').exists():
    repo_root = repo_root.parent
if not (repo_root / 'scripts').exists():
    raise RuntimeError(f'Could not resolve repository root from {Path.cwd()}')
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))
if str(repo_root / 'src') not in sys.path:
    sys.path.insert(0, str(repo_root / 'src'))
from scripts.trishift.analysis.render_refresh_figures import render
out = render('figs4')
print(f'Wrote {out}')
